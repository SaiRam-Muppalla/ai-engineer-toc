# %% [markdown]
# # Exercise 1: Vectors and Matrices with NumPy
#
# Practice the core linear algebra operations used in AI/ML.

# %%
import numpy as np

# --- VECTORS ---
# Create two vectors
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print('Vector a:', a)
print('Vector b:', b)

# TODO 1: Compute the dot product of a and b
dot_product = None  # replace with np.dot(a, b)
print('Dot product:', dot_product)

# TODO 2: Compute the L2 norm (length) of vector a
norm_a = None  # replace with np.linalg.norm(a)
print('L2 norm of a:', norm_a)

# %%
# --- MATRICES ---
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# TODO 3: Matrix multiplication (use np.matmul or @)
C = None  # replace with A @ B
print('A @ B =\n', C)

# TODO 4: Transpose of matrix A
A_T = None  # replace with A.T
print('Transpose of A:\n', A_T)

# TODO 5: Compute the determinant of A
det_A = None  # replace with np.linalg.det(A)
print('Determinant of A:', det_A)

# %%
# --- EIGENVALUES ---
# TODO 6: Compute eigenvalues and eigenvectors of A
eigenvalues, eigenvectors = np.linalg.eig(A)
print('Eigenvalues:', eigenvalues)
print('Eigenvectors:\n', eigenvectors)
